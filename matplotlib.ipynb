# %% [markdown]
# <a href="https://colab.research.google.com/github/ESRA-TUNC/Python-code/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x_values = list(range(100))
squares= [ x**2 for x in x_values]

plt.style.use("seaborn-v0_8")
fig,ax = plt.subplots()
ax.scatter(x_values,squares,s=10)

ax.set_title('Sayıların karesi',fontsize=24)
ax.set_xlabel('Sayı',fontsize=14)
ax.set_ylabel('Sayıların karesi',fontsize=14)

ax.tick_params(axis='both',labelsize=14)
plt.show()
